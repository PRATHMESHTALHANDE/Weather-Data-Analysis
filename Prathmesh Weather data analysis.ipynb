# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# # Q1) Find all records from data when the weather was exactly clear?

# %%
data[data['Weather']=='Clear'] #to display complete dataframe
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data[data['Weather']=='Clear'].shape #to view number of records
# Out:
# (1326, 8)

# %% [markdown]
# # Q2) use value counts, Find all unique weather condition

# %%
import pandas as pd

# Read the CSV file into a Pandas DataFrame
data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

# Count occurrences of each unique weather condition
weather_counts = data['Weather'].value_counts().reset_index()
weather_counts.columns = ['Weather', 'Count']

# Display the counts in a table format
print(weather_counts)
# Out:
#                                     Weather  Count
# 0                              Mainly Clear   2106
# 1                             Mostly Cloudy   2069
# 2                                    Cloudy   1728
# 3                                     Clear   1326
# 4                                      Snow    390
# 5                                      Rain    306
# 6                              Rain Showers    188
# 7                                       Fog    150
# 8                                  Rain,Fog    116
# 9                               Drizzle,Fog     80
# 10                             Snow Showers     60
# 11                                  Drizzle     41
# 12                                 Snow,Fog     37
# 13                        Snow,Blowing Snow     19
# 14                                Rain,Snow     18
# 15                                     Haze     16
# 16               Thunderstorms,Rain Showers     16
# ...

# %% [markdown]
# # Insights

# %% [markdown]
# Common Conditions:
#
# Mainly Clear, Mostly Cloudy, Cloudy, and Clear are the most frequent weather conditions, indicating a significant portion of your recorded weather falls under these categories.
# Precipitation Types:
#
# Snow, Rain, Rain Showers, Drizzle, and their combinations like Rain,Fog, Drizzle,Fog, Snow Showers, and Snow,Blowing Snow are present, showing the diversity of precipitation-related conditions.
# Visibility-Reducing Conditions:
#
# Fog is recorded quite frequently, and variations like Freezing Fog and Freezing Drizzle,Fog are also observed.
# Less Frequent or Specialized Conditions:
#
# Some weather conditions like Haze, Thunderstorms, Ice Pellets, and combinations such as Snow,Haze and Thunderstorms,Rain Showers,Fog occur less frequently.
# Extreme Conditions:
#
# There are fewer occurrences of extreme conditions like Freezing Rain, Freezing Drizzle, and their combinations with fog or other elements.
# Mixed Precipitation:
#
# Combinations like Rain,Snow, Rain,Snow,Ice Pellets, and Rain Showers,Snow Showers showcase instances of mixed precipitation.
# Rare Conditions:
#
# Some conditions such as Snow Pellets, Moderate Snow,Blowing Snow, and Drizzle,Ice Pellets,Fog occur very rarely in your dataset.

# %% [markdown]
# # Q3) Find the number of times when the wind speed was exactly 4 km/hrs

# %%
data[data['Wind Speed_km/h']==4].shape
# Out:
# (474, 8)

# %% [markdown]
# # Q4) Analysis of unique whether count to plot weather condition count bar graph

# %%
import pandas as pd
import matplotlib.pyplot as plt
data['Date/Time'] = pd.to_datetime(data['Date/Time'])

weather_counts = data['Weather'].value_counts()
print(weather_counts)
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# #  Weather Condition Counts bar graph

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

weather_counts = data['Weather'].value_counts()

plt.figure(figsize=(15, 10))
sns.barplot(x=weather_counts.index, y=weather_counts.values, palette='viridis')
plt.title('Weather Condition Counts')
plt.xlabel('Weather Condition')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q5) Humidity Distribution weather trend histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.histplot(data['Rel Hum_%'], bins=20, edgecolor='black', palette='sky blue')
plt.title('Humidity Distribution')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Q6) Finding out highest and lowest humidity date

# %% [markdown]
# # Importing highest humidity date

# %%
import pandas as pd

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

max_humidity_row = data.loc[data['Rel Hum_%'].idxmax()]

highest_humidity_date = max_humidity_row['Date/Time']

print("Date and Time when humidity was highest:", highest_humidity_date)
# Out:
# Date and Time when humidity was highest: 2012-03-17 10:00:00

# %% [markdown]
# # Importing lowest humidity date

# %%
import pandas as pd

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

min_humidity_row = data.loc[data['Rel Hum_%'].idxmin()]

lowest_humidity_date = min_humidity_row['Date/Time']

print("Date and Time when humidity was lowest:", lowest_humidity_date)
# Out:
# Date and Time when humidity was lowest: 2012-03-23 16:00:00

# %%
import pandas as pd
import matplotlib.pyplot as plt

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

plt.figure(figsize=(8, 6))
plt.hist(data['Rel Hum_%'], bins=20, edgecolor='black')
plt.title('Humidity Distribution')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('Frequency')

frequency, bins, _ = plt.hist(data['Rel Hum_%'], bins=20, edgecolor='black', alpha=0)
max_freq_index = frequency.argmax()  
max_freq_bin = bins[max_freq_index]  

date_max_frequency = data[(data['Rel Hum_%'] >= max_freq_bin) & (data['Rel Hum_%'] <= bins[max_freq_index + 1])]['Date/Time'].mode()[0]

plt.annotate(f'Date: {date_max_frequency.strftime("%Y-%m-%d %H:%M")}', xy=(max_freq_bin, max(frequency)),
             xytext=(max_freq_bin + 3, max(frequency) - 10),
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             fontsize=10)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

max_humidity_row = data.loc[data['Rel Hum_%'].idxmax()]

highest_humidity_date = max_humidity_row['Date/Time']

min_humidity_row = data.loc[data['Rel Hum_%'].idxmin()]

lowest_humidity_date = min_humidity_row['Date/Time']

print("Date and Time when humidity was highest:", highest_humidity_date)
print("Date and Time when humidity was lowest:", lowest_humidity_date)
# Out:
# Date and Time when humidity was highest: 2012-03-17 10:00:00
# Date and Time when humidity was lowest: 2012-03-23 16:00:00

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

# %% [markdown]
# # Q7) Wind Speed_km/h' velocity >50

# %%
data[(data['Wind Speed_km/h']>50)&(data['Visibility_km']!=25)]
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 671   1/28/2012 23:00     1.2              -1.7         81               52
# 1503   3/3/2012 15:00     5.3              -5.6         45               57
# 1504   3/3/2012 16:00     5.0              -5.0         48               63
# 1505   3/3/2012 17:00     4.3              -4.9         51               57
# 2718   4/23/2012 6:00     2.1              -0.3         84               52
#
#       Visibility_km  Press_kPa        Weather
# 671            16.1      99.87      Rain,Snow
# 1503           24.1      98.67  Mostly Cloudy
# 1504           48.3      98.67   Mainly Clear
# 1505           48.3      98.71   Mainly Clear
# 2718           16.1      99.66           Rain

# %% [markdown]
# # Q8) Show record where Temperature less than 0

# %%
data[data['Temp_C']<0]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
#
# ...

# %% [markdown]
# # Q9) Show record where Temperature greater than 0

# %%
data[data['Temp_C']>0]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 13      1/1/2012 13:00     0.2              -1.7         87               13
# 14      1/1/2012 14:00     0.8              -1.1         87               20
# 15      1/1/2012 15:00     1.8              -0.4         85               22
# 16      1/1/2012 16:00     2.6              -0.2         82               13
# 17      1/1/2012 17:00     3.0               0.0         81               13
# ...                ...     ...               ...        ...              ...
# 8546   12/22/2012 2:00     1.1               0.1         93               30
# 8547   12/22/2012 3:00     1.1               0.1         93               28
# 8548   12/22/2012 4:00     0.6              -0.6         92               35
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
#
# ...

# %% [markdown]
# # Q10) Plot Temperature distribution graph

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.hist(data["Temp_C"])
plt.xlabel("Temp_C")
plt.ylabel("Frequency")
plt.title("Temperature Distribution")
plt.show()

# %% [markdown]
# # Q11) Temperature was highest on which day?

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

max_temp_row = data.loc[data['Temp_C'].idxmax()]

print("Date when the temperature was highest:", max_temp_row['Date/Time'].date())
print("Highest temperature recorded:", max_temp_row['Temp_C'], "C")
# Out:
# Date when the temperature was highest: 2012-06-21
# Highest temperature recorded: 33.0 C

# %% [markdown]
# Thus temperature was highest on date 2012-06-21 which is 33.0 C

# %% [markdown]
# # Q12) Temperature was highest on which day?

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

min_temp_row = data.loc[data['Temp_C'].idxmin()]

print("Date when the temperature was lowest:", min_temp_row['Date/Time'].date())
print("Lowest temperature recorded:", min_temp_row['Temp_C'], "C")
# Out:
# Date when the temperature was lowest: 2012-01-15
# Lowest temperature recorded: -23.3 C

# %% [markdown]
# The temperature was lowest on date 2012-01-15 which is -23.3 C

# %% [markdown]
# # Q13)  Show all the paramters at 1 degree C

# %%
corr = data.corr()["Temp_C"]
print(corr)
# Out:
# Temp_C              1.000000
# Dew Point Temp_C    0.932714
# Rel Hum_%          -0.220182
# Wind Speed_km/h    -0.061876
# Visibility_km       0.273455
# Press_kPa          -0.236389
# Name: Temp_C, dtype: float64

# %% [markdown]
# # Q14) Temperature trend over time

# %%
data["Date/Time"] = pd.to_datetime(data["Date/Time"])
data.set_index("Date/Time", inplace=True)
plt.plot(data["Temp_C"])
plt.title("Temperature Trends")
plt.xlabel("Date/Time")
plt.ylabel("Temperature (°C)")
plt.show()

# %% [markdown]
# # Q15) Visibility recorded in kilometers

# %% [markdown]
# # Max Visibility in Km

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

max_visibility_row = data.loc[data['Visibility_km'].idxmax()]

print("Date with maximum visibility:", max_visibility_row['Date/Time'].date())
print("Maximum visibility recorded:", max_visibility_row['Visibility_km'], "km")
# Out:
# Date with maximum visibility: 2012-01-05
# Maximum visibility recorded: 48.3 km

# %%
data['Visibility_km'].max()
# Out:
# 48.3

# %% [markdown]
# # Weather on 2012-01-05

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

specific_date_weather = data[data['Date/Time'].dt.date == pd.to_datetime('2012-01-05').date()]

print("Weather on 2012-01-05:", specific_date_weather['Weather'].values[0])
# Out:
# Weather on 2012-01-05: Snow

# %% [markdown]
# # Min Visibility in Km

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

min_visibility_row = data.loc[data['Visibility_km'].idxmin()]

print("Date with minimum visibility:", min_visibility_row['Date/Time'].date())
print("Minimum visibility recorded:", min_visibility_row['Visibility_km'], "km")
# Out:
# Date with minimum visibility: 2012-03-17
# Minimum visibility recorded: 0.2 km

# %%
data['Visibility_km'].min()
# Out:
# 0.2

# %% [markdown]
# # Weather on 2012-03-17

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

specific_date_weather = data[data['Date/Time'].dt.date == pd.to_datetime('2012-03-17').date()]

print("Weather on 2012-03-17:", specific_date_weather['Weather'].values[0])
# Out:
# Weather on 2012-03-17: Drizzle,Fog

# %% [markdown]
# # Q16) My data consist of for how many years , Can you find out?

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

data['Year'] = data['Date/Time'].dt.year

unique_years = data['Year'].nunique()

print("Number of unique years in the dataset:", unique_years)
# Out:
# Number of unique years in the dataset: 1

# %% [markdown]
# # Thus my dataset have only one year that is 2012 is the answer

# %% [markdown]
# # Q17) Plot line graph count of month for whole year

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

data['Month'] = data['Date/Time'].dt.month
weather_condition = 'Mainly Clear'  

specific_weather = data[data['Weather'] == weather_condition]

max_occurrences_per_month = specific_weather.groupby('Month').size().max(level=0).reset_index(name='Occurrences')

plt.figure(figsize=(10, 6))
sns.lineplot(data=max_occurrences_per_month, x='Month', y='Occurrences', marker='o', linestyle='-')
plt.title(f'Highest Occurrences of {weather_condition} for Each Month')
plt.xlabel('Month')
plt.ylabel('Occurrences')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.show()

# %% [markdown]
# # Q18) Can you plot distribution of different weather conditions for whole year in pie chart?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

data['Month'] = data['Date/Time'].dt.month

fig, axs = plt.subplots(4, 3, figsize=(15, 15))
axs = axs.flatten()

for i, month in enumerate(range(1, 13)):
 
    specific_month_data = data[data['Month'] == month]
    
    weather_counts = specific_month_data['Weather'].value_counts()
    
    labels = weather_counts.index
    sizes = weather_counts.values
    axs[i].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    axs[i].set_title(f"Weather Distribution - Month {month}")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Q19) Can you plot bubble chart with different colours for each weather conditions for month for all 12 months?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

data['Month'] = data['Date/Time'].dt.month

unique_conditions = data['Weather'].unique()
num_conditions = len(unique_conditions)
colors = sns.color_palette("husl", num_conditions)

fig, axs = plt.subplots(4, 3, figsize=(15, 15))
axs = axs.flatten()

for i, month in enumerate(range(1, 13)):
    
    specific_month_data = data[data['Month'] == month]
    
    color_dict = {condition: colors[j] for j, condition in enumerate(unique_conditions)}
    specific_month_data['Color'] = specific_month_data['Weather'].map(color_dict)
    
    sns.scatterplot(ax=axs[i], data=specific_month_data, x='Month', y='Weather', size='Visibility_km',
                    sizes=(30, 500), hue='Weather', palette=color_dict, legend=False)
    axs[i].set_title(f"Weather Distribution - Month {month}")
    axs[i].set_xlabel('Month')
    axs[i].set_ylabel('Weather')
    axs[i].set_yticklabels(axs[i].get_yticks(), rotation=45)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-0c352bd33a28>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   specific_month_data['Color'] = specific_month_data['Weather'].map(color_dict)
# <ipython-input-15-0c352bd33a28>:38: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels(axs[i].get_yticks(), rotation=45)
# <ipython-input-15-0c352bd33a28>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r"C:\Users\roari\Downloads\1. Weather Data.csv")

data['Date/Time'] = pd.to_datetime(data['Date/Time'])

data['Month'] = data['Date/Time'].dt.month

unique_conditions = data['Weather'].unique()
num_conditions = len(unique_conditions)
colors = sns.color_palette("husl", num_conditions)

fig, axs = plt.subplots(4, 3, figsize=(15, 15))
axs = axs.flatten()

for i, month in enumerate(range(1, 13)):
   
    specific_month_data = data[data['Month'] == month]
    
    color_dict = {condition: colors[j] for j, condition in enumerate(unique_conditions)}
    specific_month_data['Color'] = specific_month_data['Weather'].map(color_dict)
    
    sns.scatterplot(ax=axs[i], data=specific_month_data, x='Month', y='Weather', size='Visibility_km',
                    sizes=(30, 500), hue='Weather', palette=color_dict, legend=False)
    axs[i].set_title(f"Weather Distribution - Month {month}")
    axs[i].set_xlabel('Month')
    axs[i].set_ylabel('Weather')
    axs[i].set_yticklabels(axs[i].get_yticks(), rotation=45)

handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, label=condition)
           for condition, color in zip(unique_conditions, colors)]
plt.legend(handles=handles, title='Weather Condition', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-e1963d3522e8>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   specific_month_data['Color'] = specific_month_data['Weather'].map(color_dict)
# <ipython-input-16-e1963d3522e8>:38: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels(axs[i].get_yticks(), rotation=45)
# <ipython-input-16-e1963d3522e8>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
